# %%
from queues import Queue

# %%
fifo = Queue()

# %%
fifo.enqueue("1st")
fifo.enqueue("2nd")
fifo.enqueue("3rd")

# %%
fifo.dequeue()
# Out:
# '1st'

# %%
fifo.dequeue()
# Out:
# '2nd'

# %%
fifo.dequeue()
# Out:
# '3rd'

# %%
from queues import Queue

# %%
fifo = Queue("1st", "2nd", "3rd")

# %%
len(fifo)
# Out:
# 3

# %%
for element in fifo:
# Out:
#   Cell In[15], line 1
#     for element in fifo:
#                         ^
# SyntaxError: incomplete input

# %%
for element in fifo:
    print(element)
# Out:
# 1st
# 2nd
# 3rd

# %%
len(fifo)
# Out:
# 0
