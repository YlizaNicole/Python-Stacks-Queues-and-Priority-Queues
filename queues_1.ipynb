# %%
from dataclasses import dataclass

@dataclass
class Message:
    event: str


wipers = Message("Windshield wipers turned on")
hazard_lights = Message("Hazard lights turned on")

wipers < hazard_lights
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 11
#       8 wipers = Message("Windshield wipers turned on")
#       9 hazard_lights = Message("Hazard lights turned on")
# ---> 11 wipers < hazard_lights
#
# TypeError: '<' not supported between instances of 'Message' and 'Message'

# %%
messages = PriorityQueue()
messages.enqueue_with_priority(CRITICAL, wipers)
messages.enqueue_with_priority(IMPORTANT, hazard_lights)

# %%
messages.enqueue_with_priority(CRITICAL, Message("ABS engaged"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 messages.enqueue_with_priority(CRITICAL, Message("ABS engaged"))
#
# File c:\Users\hansz\Documents\DSA\queues.py:9, in PriorityQueue.enqueue_with_priority(self, priority, value)
#       <a href='file:///c%3A/Users/hansz/Documents/DSA/queues.py?line=7'>8</a> def enqueue_with_priority(self, priority, value):
# ----> <a href='file:///c%3A/Users/hansz/Documents/DSA/queues.py?line=8'>9</a>     heappush(self._elements, (-priority, value))
#
# TypeError: '<' not supported between instances of 'Message' and 'Message'
