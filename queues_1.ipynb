# %%
from queues import Queue

# %%
fifo = Queue()

# %%
fifo.enqueue("1st")
fifo.enqueue("2nd")
fifo.enqueue("3rd")

# %%
fifo.dequeue()
# Out:
# '1st'

# %%
fifo.dequeue()
# Out:
# '2nd'

# %%
fifo.dequeue()
# Out:
# '3rd'
